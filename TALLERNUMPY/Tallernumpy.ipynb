# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from PIL import Image

A=np.random.randint(0, 101,size=(5,3))
print(f"Vector A\n{A}")
print(f"La suma del vector es {A.sum()}")
print(f"El promedio del vector es {A.mean()}")

print("\n------Vector de 10x10 aleatorio en rango 0-9---------------")
B=np.random.randint(0, 10,size=(10,10))
print(B)
print("\nValores mayores que 5 remplazados por -1")
B[B>5]=-1
print(B)
print("\nIMAGEN")
img = Image.open('.\Pikachu_de_Ash_en_Alola.png').convert('RGB')
img_array = np.array(img)
print(f"\nSHAPE {img_array.shape}")
print(f"\nMIN {img_array.min()}")
print(f"\nMAX {img_array.max()}")
print(f"\nPROM {img_array.mean()}")
plt.imshow(img_array)
plt.show()
# Out:
# Vector A
# [[79 95 23]
#  [35 75 67]
#  [ 9 66 11]
#  [65 11 63]
#  [80 95 62]]
# La suma del vector es 836
# El promedio del vector es 55.733333333333334
#
# ------Vector de 10x10 aleatorio en rango 0-9---------------
# [[3 5 9 7 5 5 6 6 4 3]
#  [3 4 3 1 1 0 9 8 6 0]
#  [6 3 7 8 6 8 6 5 2 4]
#  [9 3 3 4 3 5 8 3 0 5]
#  [3 8 6 1 6 7 6 0 6 7]
#  [9 1 2 1 3 1 3 8 3 2]
#  [5 3 5 1 2 8 7 7 9 8]
#  [1 7 2 0 0 2 8 5 6 9]
#  [9 1 7 7 3 7 0 8 9 6]
#  [0 3 4 4 7 4 1 4 2 2]]
#
# Valores mayores que 5 remplazados por -1
# [[ 3  5 -1 -1  5  5 -1 -1  4  3]
#  [ 3  4  3  1  1  0 -1 -1 -1  0]
#  [-1  3 -1 -1 -1 -1 -1  5  2  4]
#  [-1  3  3  4  3  5 -1  3  0  5]
#  [ 3 -1 -1  1 -1 -1 -1  0 -1 -1]
#  [-1  1  2  1  3  1  3 -1  3  2]
#  [ 5  3  5  1  2 -1 -1 -1 -1 -1]
#  [ 1 -1  2  0  0  2 -1  5 -1 -1]
#  [-1  1 -1 -1  3 -1  0 -1 -1 -1]
#  [ 0  3  4  4 -1  4  1  4  2  2]]
#
# IMAGEN
#
# SHAPE (1080, 1920, 3)
#
# MIN 0
#
# MAX 251
#
# PROM 162.62498730066872
